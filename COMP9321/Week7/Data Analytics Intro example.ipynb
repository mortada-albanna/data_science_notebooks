# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression

df = pd.DataFrame({
    "month": ["Jan","Feb","Mar","Apr","May"],
    "sales": [100,120,90,150,170],
    "marketing_spend": [20,25,15,30,35]
})

df
# Out:
#   month  sales  marketing_spend
# 0   Jan    100               20
# 1   Feb    120               25
# 2   Mar     90               15
# 3   Apr    150               30
# 4   May    170               35

# %%
# What is the average sales?

average_sales = df["sales"].mean()

print("Average sales:", average_sales)
# Out:
# Average sales: 126.0

# %%
# Which month had the highest sales?

max_row = df.loc[df["sales"].idxmax()]

print("Month with highest sales:", max_row["month"])

print("Highest sales value:", max_row["sales"])
# Out:
# Month with highest sales: May
# Highest sales value: 170

# %%
# Is marketing correlated with sales?

correlation = df["sales"].corr(df["marketing_spend"])

print("Correlation between marketing spend and sales:", correlation)
# Out:
# Correlation between marketing spend and sales: 0.9877569118027772

# %%
# Plot the sales trend
df.plot(kind="line", x="month", y="sales", marker="o", legend=False)

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %%
X = df[["marketing_spend"]]   # independent variable
y = df["sales"]               # dependent variable

model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print("Intercept (a):", model.intercept_)
print("Slope (b):", model.coef_[0])
# Out:
# Intercept (a): 21.000000000000014
# Slope (b): 4.199999999999999

# %%
# Plot original data
df.plot(kind="scatter", x="marketing_spend", y="sales")

# Plot regression line
plt.plot(df["marketing_spend"], model.predict(X))

plt.title("Linear Regression: Marketing vs Sales")
plt.xlabel("Marketing Spend")
plt.ylabel("Sales")

plt.show()

# %%
model.predict([[19]])
#model.predict([[50]])
# Out:
# C:\Users\morta\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([100.8])
