# %%
import pandas as pd
import numpy as np

raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy', np.nan], 
        'last_name': ['Miller', 'Jacobson', np.nan, 'Milner', 'Cooze', np.nan], 
        'age': [42, 52, 36, 24, 73, np.nan], 
        'preTestScore': [4, 24, 31, np.nan, np.nan, np.nan],
        'postTestScore': ["25,000", "94,000", 57, 62, 70, np.nan],
           np.nan:np.nan}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'preTestScore', 'postTestScore', np.nan])

# %%
df
# Out:
#   first_name last_name   age  preTestScore postTestScore  NaN
# 0      Jason    Miller  42.0           4.0        25,000  NaN
# 1      Molly  Jacobson  52.0          24.0        94,000  NaN
# 2       Tina       NaN  36.0          31.0            57  NaN
# 3       Jake    Milner  24.0           NaN            62  NaN
# 4        Amy     Cooze  73.0           NaN            70  NaN
# 5        NaN       NaN   NaN           NaN           NaN  NaN

# %%
df.notnull()
# Out:
#    first_name  last_name   age  preTestScore  postTestScore    NaN
# 0        True       True  True          True           True  False
# 1        True       True  True          True           True  False
# 2        True      False  True          True           True  False
# 3        True       True  True         False           True  False
# 4        True       True  True         False           True  False

# %%
df[df['preTestScore'].notnull()]
# Out:
#   first_name last_name  age  preTestScore postTestScore  NaN
# 0      Jason    Miller   42           4.0        25,000  NaN
# 1      Molly  Jacobson   52          24.0        94,000  NaN
# 2       Tina       NaN   36          31.0            57  NaN

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, age, preTestScore, postTestScore, nan]
# Index: []

# %%
df.dropna(how='all')
# Out:
#   first_name last_name   age  preTestScore postTestScore  NaN
# 0      Jason    Miller  42.0           4.0        25,000  NaN
# 1      Molly  Jacobson  52.0          24.0        94,000  NaN
# 2       Tina       NaN  36.0          31.0            57  NaN
# 3       Jake    Milner  24.0           NaN            62  NaN
# 4        Amy     Cooze  73.0           NaN            70  NaN

# %%
cleaned= df

cleaned.dropna(how='all', inplace=True)
cleaned
# Out:
#   first_name last_name   age  preTestScore postTestScore  NaN
# 0      Jason    Miller  42.0           4.0        25,000  NaN
# 1      Molly  Jacobson  52.0          24.0        94,000  NaN
# 2       Tina       NaN  36.0          31.0            57  NaN
# 3       Jake    Milner  24.0           NaN            62  NaN
# 4        Amy     Cooze  73.0           NaN            70  NaN

# %%
cleaned.fillna({'preTestScore': 20, 'last_name': 'Doe'}, inplace=True)
cleaned
# Out:
#   first_name last_name   age  preTestScore postTestScore  NaN
# 0      Jason    Miller  42.0           4.0        25,000  NaN
# 1      Molly  Jacobson  52.0          24.0        94,000  NaN
# 2       Tina       Doe  36.0          31.0            57  NaN
# 3       Jake    Milner  24.0          20.0            62  NaN
# 4        Amy     Cooze  73.0          20.0            70  NaN

# %%
cleaned.dropna(axis=1, how='all')
# Out:
#   first_name last_name   age  preTestScore postTestScore
# 0      Jason    Miller  42.0           4.0        25,000
# 1      Molly  Jacobson  52.0          24.0        94,000
# 2       Tina       Doe  36.0          31.0            57
# 3       Jake    Milner  24.0          20.0            62
# 4        Amy     Cooze  73.0          20.0            70

# %%
dirty_df = df
dirty_df.assign(column1=np.nan)
dirty_df.at[4, 'first_name']=np.nan
dirty_df
# Out:
#   first_name last_name   age  preTestScore postTestScore  NaN
# 0      Jason    Miller  42.0           4.0        25,000  NaN
# 1      Molly  Jacobson  52.0          24.0        94,000  NaN
# 2       Tina       Doe  36.0          31.0            57  NaN
# 3       Jake    Milner  24.0          20.0            62  NaN
# 4        NaN     Cooze  73.0          20.0            70  NaN

# %%
dirty_df.dropna(thresh=5)
# Out:
#   first_name last_name   age  preTestScore postTestScore  NaN
# 0      Jason    Miller  42.0           4.0        25,000  NaN
# 1      Molly  Jacobson  52.0          24.0        94,000  NaN
# 2       Tina       Doe  36.0          31.0            57  NaN
# 3       Jake    Milner  24.0          20.0            62  NaN
